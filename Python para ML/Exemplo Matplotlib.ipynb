# %%
import matplotlib

# %%
#função para trabalhar com regressão
from sklearn.datasets import make_regression
#gerando amostras iniciais usando método de regressão com 
# 200 exemplos com características de 1 unidade com taxa de erro de 30 unidades
x, y = make_regression(n_samples=200, n_features=1, noise=30)
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
